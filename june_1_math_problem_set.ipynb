# %% [markdown]
# Jeff King
#
# Problem 1a

# %% [markdown]
# \begin{equation}
# f(x) = ln(x^4)sin(x^3)
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{dy}{dx} = \frac{1}{x^4} 4x^3 sin(x^3) + ln(x^4)cos(x^3)3x^2
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{dy}{dx} = \frac{4sin(x^3)}{x} + 3x^2ln(x^4)cos(x^3)
# \end{equation}

# %% [markdown]
# Problem 1b

# %% [markdown]
# \begin{equation}
# f(x) = \frac{1}{1 +e^{-x}}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{dy}{dx} = \frac{0 \cdot (1 + e^{-x}) - (-e^{-x})}{(1 + e^{-x})^2}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{dy}{dx} = \frac{e^{-x}}{(1 + e^{-x})^2}
# \end{equation}

# %% [markdown]
# Problem 1c

# %% [markdown]
# \begin{equation}
# e^{-\frac{1}{2\sigma^2}(x - \mu)^2}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{dy}{dx} = e^{-\frac{1}{2\sigma^2}(x - \mu)^2}\left(-\frac{1}{\sigma^2}(x - \mu)\right)
# \end{equation}

# %% [markdown]
# Problem 2a

# %% [markdown]
# \begin{equation}
# f(x) = 7x^2 -3x + 5
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{dy}{dx} = 14x - 3
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{d^2y}{dx^2} = 14
# \end{equation}

# %% [markdown]
# \begin{equation}
# 14x - 3 = 0  => x = \frac{3}{14}
# \end{equation}

# %% [markdown]
# The second derivative is a positive constant so $ f(x) $ has a local minimum at $ x = \frac{3}{14}  $

# %% [raw]
# Problem 2b

# %% [markdown]
# \begin{equation}
# f(x) = x^3 - 2x^2 + x + 1
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{dy}{dx} = 3x^2 - 4x + 1
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{d^2y}{dx^2} = 6x - 4
# \end{equation}

# %% [markdown]
# \begin{equation}
# 3x^2 - 4x + 1 = 0 =>
# (3x - 1)(x - 1) = 0
# \end{equation}
# \begin{equation}
# x = \frac{1}{3}
# \end{equation}
# \begin{equation}
# x = 1
# \end{equation}

# %% [markdown]
# At $ x = 2 $, the second derivative evaluates to $ 6\left(\frac{1}{3}\right) - 4 = -2 $ so $ f(x) $ has a a local maximum at $ x = \frac{1}{3} $.

# %% [markdown]
# At $ x = 1 $, the second derivative evaluates to $ 6(1) - 4 = 2 $, so $ f(x) $ has a local maximum at $ x = 1 $

# %% [markdown]
# Problem 2c

# %% [markdown]
# \begin{equation}
# f(x) = x^{\frac{2}{3}}
# \end{equation}
# \begin{equation}
# \frac{dy}{dx} = \frac{2x^{\frac{-1}{3}}}{3}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{d^2y}{dx^2} = \frac{-2x^{\frac{-4}{3}}}{9}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \frac{2x^{\frac{-1}{3}}}{3} = 0 => x = 0
# \end{equation}

# %% [markdown]
# At $ x = 0 $, second derivative is 0
#
# Because  $ f(x) $ is not defined for $ x < 0 $ and $ \frac{dy}{dx} $ is positive for $ x > 0 $ then $ f(x) $ is increasing over its range and $ f(0) = 0 $ is the minimum value.

# %% [raw]
# Problem 3a

# %% [markdown]
# \begin{equation}
# f(x) = 7x^2 - 3x + 5
# \end{equation}
# \begin{equation}
# \frac{dy}{dx} = 14x^2 - 3
# \end{equation}

# %% [markdown]
# \begin{equation}
# f(0) = 5
# \end{equation}
# \begin{equation}
# f^{(1)}(0) = -3
# \end{equation}

# %% [markdown]
# \begin{equation}
# p(x) = 5 - 3x
# \end{equation}

# %% [markdown]
# $  p(1) = 2 $ and $ f(1) = 7 - 3 + 5 = 9 $ so the error is $ -7 $

# %% [markdown]
# Problem 3b

# %% [markdown]
# \begin{equation}
# f(x) = x^3 -2x^2 + x + 1
# \end{equation}

# %% [markdown]
# \begin{equation}
# f(0) = 1 and f^{(1)}(0) = 1 => p(x) = 1 + x
# \end{equation}

# %% [markdown]
# \begin{equation}
# p(1) = 2
# \end{equation}
# \begin{equation}
# f(1) = 1
# \end{equation}

# %% [markdown]
# So the error $ = 1 $

# %% [markdown]
# Problem 3c
#
# Every derivative of $ x^{\frac{2}{3}} $ is $ 0 $ at $ x = 0 $ so a Maclaurin approximation does not exist.

# %% [markdown]
# Problem 4: Challenge problem

# %% [markdown]
# \begin{equation}
# f(x,y) = (x + 2y - 7)^2 + (2x + y - 5)^2
# \end{equation}

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
  
x = np.outer(np.linspace(-10, 10, 10), np.ones(10))
y = x.copy().T
z = (x + 2 * y - 7) ** 2 + (2 * x + y -5) ** 2
  
fig = plt.figure(figsize=(10, 10), dpi=80)
  
ax = plt.axes(projection ='3d')
  
ax.plot_surface(x, y, z, cmap ='viridis', edgecolor ='green')
ax.set_title('Booth')
plt.show()

# %% [markdown]
# \begin{equation}
# \nabla f = \begin{bmatrix} 2(x + 2y - 7)^2 + 4(2x + y - 5)^2 \\ 4(x + 2y - 7) + 2(2x + y - 5) \end{bmatrix}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \nabla f = \begin{bmatrix} 10x + 8y - 34 \\ 8x + 10y - 38 \end{bmatrix}
# \end{equation}

# %% [markdown]
# We want to minimize:

# %% [markdown]
# \begin{equation}
# \begin{bmatrix} 10 & 8 & 34 \\ 8 & 10 & 38  \end{bmatrix}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \begin{bmatrix} 1 & .8 & 3.4 \\ 0 & -3.6 & -10.8  \end{bmatrix}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \begin{bmatrix} 1 & .8 & 3.4 \\ 0 & -3.6 & -10.8  \end{bmatrix}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \begin{bmatrix} 1 & 0 & 1 \\ 0 & 1 & 3  \end{bmatrix}
# \end{equation}

# %% [markdown]
# We have a minimum at $ f(1,3) $
