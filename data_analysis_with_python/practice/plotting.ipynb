# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.figure(figsize=(12,6))
plt.title('my dumb plot')

plt.subplot(1,2,1)
plt.plot(x, x ** 2)
plt.plot([0,0,0], [-10, 0, 100])
plt.plot([0, 10], [0, 0])
plt.legend(['X^2', 'Vertical Line', 'Horizontal Line'])
plt.xlabel('X')
plt.ylabel('X ** 2')


plt.subplot(1,2,2)
plt.plot(x, -(x ** 2))
plt.plot(([]))
